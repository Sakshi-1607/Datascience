# %% [markdown]
# ### Lab Title: Exploring Correlation and Covariance in Manufacturing Industry Data

# %% [markdown]
# #### Problem Statement:
# Understanding the relationship between different variables in the manufacturing industry is crucial for optimizing processes and improving efficiency. Correlation and covariance help in identifying dependencies between key factors such as productivity, idle time, over time, and incentives.

# %% [markdown]
# #### Objective:
# - Compute the correlation and covariance between different manufacturing metrics.
# - Interpret these measures to understand dependencies and trends.

# %% [markdown]
# #### Dataset:
# The dataset is taken from [Kaggle](https://www.kaggle.com/datasets/ishadss/productivity-prediction-of-garment-employees)

# %% [markdown]
# #### Requirements:
# - Python installed (version 3.x recommended).
# - Pandas and NumPy libraries installed (`pip install pandas numpy`).
# - Jupyter Notebook (optional but recommended for running the lab).

# %% [markdown]
# #### Implementation:

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# %%
# Load dataset
df=pd.read_csv("garments_worker_productivity.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1197 non-null   object
#  1   quarter                1197 non-null   object
#  2   department             1197 non-null   object
#  3   day                    1197 non-null   object
#  4   team                   1197 non-null   int64
#  5   targeted_productivity  1197 non-null   float64
#  6   smv                    1197 non-null   float64
#  7   wip                    691 non-null    float64
#  8   over_time              1197 non-null   int64
#  9   incentive              1197 non-null   int64
#  10  idle_time              1197 non-null   float64
#  11  idle_men               1197 non-null   int64
#  12  no_of_style_change     1197 non-null   int64
#  13  no_of_workers          1197 non-null   float64
#  14  actual_productivity    1197 non-null   float64
# dtypes: float64(6), int64(5), object(4)
# memory usage: 140.4+ KB

# %%
df.columns
# Out:
# Index(['date', 'quarter', 'department', 'day', 'team', 'targeted_productivity',
#        'smv', 'wip', 'over_time', 'incentive', 'idle_time', 'idle_men',
#        'no_of_style_change', 'no_of_workers', 'actual_productivity'],
#       dtype='object')

# %%
data1=df[['team', 'targeted_productivity',
       'smv', 'wip', 'over_time', 'incentive', 'idle_time', 'idle_men',
       'no_of_style_change', 'no_of_workers', 'actual_productivity']]
data1
# Out:
#       team  targeted_productivity    smv     wip  over_time  incentive  \
# 0        8                   0.80  26.16  1108.0       7080         98
# 1        1                   0.75   3.94     NaN        960          0
# 2       11                   0.80  11.41   968.0       3660         50
# 3       12                   0.80  11.41   968.0       3660         50
# 4        6                   0.80  25.90  1170.0       1920         50
# ...    ...                    ...    ...     ...        ...        ...
# 1192    10                   0.75   2.90     NaN        960          0
# 1193     8                   0.70   3.90     NaN        960          0
# 1194     7                   0.65   3.90     NaN        960          0
# 1195     9                   0.75   2.90     NaN       1800          0
# 1196     6                   0.70   2.90     NaN        720          0
#
#       idle_time  idle_men  no_of_style_change  no_of_workers  \
# 0           0.0         0                   0           59.0
# 1           0.0         0                   0            8.0
# 2           0.0         0                   0           30.5
# 3           0.0         0                   0           30.5
# 4           0.0         0                   0           56.0
# ...         ...       ...                 ...            ...
# 1192        0.0         0                   0            8.0
# 1193        0.0         0                   0            8.0
# 1194        0.0         0                   0            8.0
# 1195        0.0         0                   0           15.0
# 1196        0.0         0                   0            6.0
#
#       actual_productivity
# 0                0.940725
# 1                0.886500
# 2                0.800570
# 3                0.800570
# 4                0.800382
# ...                   ...
# 1192             0.628333
# 1193             0.625625
# 1194             0.625625
# 1195             0.505889
# 1196             0.394722
#
# [1197 rows x 11 columns]

# %%
# Select relevant numerical columns for analysis
selected_columns=['team','targeted_productivity','smv','wip','over_time',
                  'incentive','idle_time','idle_men','no_of_style_change',
                  'no_of_workers','actual_productivity']
data=df[selected_columns]
data
# Out:
#       team  targeted_productivity    smv     wip  over_time  incentive  \
# 0        8                   0.80  26.16  1108.0       7080         98
# 1        1                   0.75   3.94     NaN        960          0
# 2       11                   0.80  11.41   968.0       3660         50
# 3       12                   0.80  11.41   968.0       3660         50
# 4        6                   0.80  25.90  1170.0       1920         50
# ...    ...                    ...    ...     ...        ...        ...
# 1192    10                   0.75   2.90     NaN        960          0
# 1193     8                   0.70   3.90     NaN        960          0
# 1194     7                   0.65   3.90     NaN        960          0
# 1195     9                   0.75   2.90     NaN       1800          0
# 1196     6                   0.70   2.90     NaN        720          0
#
#       idle_time  idle_men  no_of_style_change  no_of_workers  \
# 0           0.0         0                   0           59.0
# 1           0.0         0                   0            8.0
# 2           0.0         0                   0           30.5
# 3           0.0         0                   0           30.5
# 4           0.0         0                   0           56.0
# ...         ...       ...                 ...            ...
# 1192        0.0         0                   0            8.0
# 1193        0.0         0                   0            8.0
# 1194        0.0         0                   0            8.0
# 1195        0.0         0                   0           15.0
# 1196        0.0         0                   0            6.0
#
#       actual_productivity
# 0                0.940725
# 1                0.886500
# 2                0.800570
# 3                0.800570
# 4                0.800382
# ...                   ...
# 1192             0.628333
# 1193             0.625625
# 1194             0.625625
# 1195             0.505889
# 1196             0.394722
#
# [1197 rows x 11 columns]

# %%
# Compute covariance
cov_matrix=data.cov()

# Compute correlation
corr_matrix=data.corr()

# %%
# Print results
print("Covariance Matrix:\n", cov_matrix)
print("Correlation Matrix:\n", corr_matrix)
# Out:
# Covariance Matrix:
#                                team  targeted_productivity           smv  \
# team                     11.999042               0.010266     -4.170167
# targeted_productivity     0.010266               0.009583     -0.074439
# smv                      -4.170167              -0.074439    119.754046
# wip                    -212.712691              11.630780   -485.038033
# over_time             -1122.167410             -29.030617  24732.539468
# incentive                -4.258009               0.513815     57.195571
# idle_time                 0.167131              -0.069899      7.908797
# idle_men                  0.305443              -0.017222      3.788411
# no_of_style_change       -0.016590              -0.008766      1.476655
# no_of_workers            -5.775617              -0.183154    221.580535
# actual_productivity      -0.089909               0.007201     -0.233124
#
#                                 wip     over_time     incentive    idle_time  \
# team                  -2.127127e+02 -1.122167e+03     -4.258009     0.167131
# targeted_productivity  1.163078e+01 -2.903062e+01      0.513815    -0.069899
# smv                   -4.850380e+02  2.473254e+04     57.195571     7.908797
# wip                    3.376241e+06  1.173852e+05   8478.812114  -807.632285
# over_time              1.173852e+05  1.121462e+07  -2571.212375  1321.044885
# incentive              8.478812e+03 -2.571212e+03  25658.479053   -24.478679
# idle_time             -8.076323e+02  1.321045e+03    -24.478679   161.537911
# idle_men              -3.834594e+02 -1.961016e+02    -11.069442    23.231413
# no_of_style_change    -7.142011e+01  8.566651e+01     -1.823491    -0.063067
# no_of_workers          5.257543e+02  5.457493e+04    175.018659    16.377286
# actual_productivity    3.729937e+01 -3.167405e+01      2.139222    -0.179303
#
#                          idle_men  no_of_style_change  no_of_workers  \
# team                     0.305443           -0.016590      -5.775617
# targeted_productivity   -0.017222           -0.008766      -0.183154
# smv                      3.788411            1.476655     221.580535
# wip                   -383.459374          -71.420114     525.754311
# over_time             -196.101555           85.666507   54574.928067
# incentive              -11.069442           -1.823491     175.018659
# idle_time               23.231413           -0.063067      16.377286
# idle_men                10.686278            0.186901       7.760404
# no_of_style_change       0.186901            0.183054       3.113065
# no_of_workers            7.760404            3.113065     492.737294
# actual_productivity     -0.103661           -0.015481      -0.224611
#
#                        actual_productivity
# team                             -0.089909
# targeted_productivity             0.007201
# smv                              -0.233124
# wip                              37.299365
# over_time                       -31.674054
# incentive                         2.139222
# idle_time                        -0.179303
# idle_men                         -0.103661
# no_of_style_change               -0.015481
# no_of_workers                    -0.224611
# actual_productivity               0.030446
# Correlation Matrix:
#                             team  targeted_productivity       smv       wip  \
# team                   1.000000               0.030274 -0.110011 -0.033474
# targeted_productivity  0.030274               1.000000 -0.069489  0.062054
# smv                   -0.110011              -0.069489  1.000000 -0.037837
# wip                   -0.033474               0.062054 -0.037837  1.000000
# over_time             -0.096737              -0.088557  0.674887  0.022302
# incentive             -0.007674               0.032768  0.032629  0.167210
# idle_time              0.003796              -0.056181  0.056863 -0.026299
# idle_men               0.026974              -0.053818  0.105901 -0.048718
# no_of_style_change    -0.011194              -0.209294  0.315388 -0.072357
# no_of_workers         -0.075113              -0.084288  0.912176  0.030383
# actual_productivity   -0.148753               0.421594 -0.122089  0.131147
#
#                        over_time  incentive  idle_time  idle_men  \
# team                   -0.096737  -0.007674   0.003796  0.026974
# targeted_productivity  -0.088557   0.032768  -0.056181 -0.053818
# smv                     0.674887   0.032629   0.056863  0.105901
# wip                     0.022302   0.167210  -0.026299 -0.048718
# over_time               1.000000  -0.004793   0.031038 -0.017913
# incentive              -0.004793   1.000000  -0.012024 -0.021140
# idle_time               0.031038  -0.012024   1.000000  0.559146
# idle_men               -0.017913  -0.021140   0.559146  1.000000
# no_of_style_change      0.059790  -0.026607  -0.011598  0.133632
# no_of_workers           0.734164   0.049222   0.058049  0.106946
# actual_productivity    -0.054206   0.076538  -0.080851 -0.181734
#
#                        no_of_style_change  no_of_workers  actual_productivity
# team                            -0.011194      -0.075113            -0.148753
# targeted_productivity           -0.209294      -0.084288             0.421594
# smv                              0.315388       0.912176            -0.122089
# wip                             -0.072357       0.030383             0.131147
# over_time                        0.059790       0.734164            -0.054206
# incentive                       -0.026607       0.049222             0.076538
# idle_time                       -0.011598       0.058049            -0.080851
# idle_men                         0.133632       0.106946            -0.181734
# no_of_style_change               1.000000       0.327787            -0.207366
# no_of_workers                    0.327787       1.000000            -0.057991
# actual_productivity             -0.207366      -0.057991             1.000000

# %%
cov_matrix
# Out:
#                               team  targeted_productivity           smv  \
# team                     11.999042               0.010266     -4.170167
# targeted_productivity     0.010266               0.009583     -0.074439
# smv                      -4.170167              -0.074439    119.754046
# wip                    -212.712691              11.630780   -485.038033
# over_time             -1122.167410             -29.030617  24732.539468
# incentive                -4.258009               0.513815     57.195571
# idle_time                 0.167131              -0.069899      7.908797
# idle_men                  0.305443              -0.017222      3.788411
# no_of_style_change       -0.016590              -0.008766      1.476655
# no_of_workers            -5.775617              -0.183154    221.580535
# actual_productivity      -0.089909               0.007201     -0.233124
#
#                                 wip     over_time     incentive    idle_time  \
# team                  -2.127127e+02 -1.122167e+03     -4.258009     0.167131
# targeted_productivity  1.163078e+01 -2.903062e+01      0.513815    -0.069899
# smv                   -4.850380e+02  2.473254e+04     57.195571     7.908797
# wip                    3.376241e+06  1.173852e+05   8478.812114  -807.632285
# over_time              1.173852e+05  1.121462e+07  -2571.212375  1321.044885
# incentive              8.478812e+03 -2.571212e+03  25658.479053   -24.478679
# idle_time             -8.076323e+02  1.321045e+03    -24.478679   161.537911
# idle_men              -3.834594e+02 -1.961016e+02    -11.069442    23.231413
# no_of_style_change    -7.142011e+01  8.566651e+01     -1.823491    -0.063067
# no_of_workers          5.257543e+02  5.457493e+04    175.018659    16.377286
# actual_productivity    3.729937e+01 -3.167405e+01      2.139222    -0.179303
#
#                          idle_men  no_of_style_change  no_of_workers  \
# team                     0.305443           -0.016590      -5.775617
# targeted_productivity   -0.017222           -0.008766      -0.183154
# smv                      3.788411            1.476655     221.580535
# wip                   -383.459374          -71.420114     525.754311
# over_time             -196.101555           85.666507   54574.928067
# incentive              -11.069442           -1.823491     175.018659
# idle_time               23.231413           -0.063067      16.377286
# idle_men                10.686278            0.186901       7.760404
# no_of_style_change       0.186901            0.183054       3.113065
# no_of_workers            7.760404            3.113065     492.737294
# actual_productivity     -0.103661           -0.015481      -0.224611
#
#                        actual_productivity
# team                             -0.089909
# targeted_productivity             0.007201
# smv                              -0.233124
# wip                              37.299365
# over_time                       -31.674054
# incentive                         2.139222
# idle_time                        -0.179303
# idle_men                         -0.103661
# no_of_style_change               -0.015481
# no_of_workers                    -0.224611
# actual_productivity               0.030446

# %%
corr_matrix
# Out:
#                            team  targeted_productivity       smv       wip  \
# team                   1.000000               0.030274 -0.110011 -0.033474
# targeted_productivity  0.030274               1.000000 -0.069489  0.062054
# smv                   -0.110011              -0.069489  1.000000 -0.037837
# wip                   -0.033474               0.062054 -0.037837  1.000000
# over_time             -0.096737              -0.088557  0.674887  0.022302
# incentive             -0.007674               0.032768  0.032629  0.167210
# idle_time              0.003796              -0.056181  0.056863 -0.026299
# idle_men               0.026974              -0.053818  0.105901 -0.048718
# no_of_style_change    -0.011194              -0.209294  0.315388 -0.072357
# no_of_workers         -0.075113              -0.084288  0.912176  0.030383
# actual_productivity   -0.148753               0.421594 -0.122089  0.131147
#
#                        over_time  incentive  idle_time  idle_men  \
# team                   -0.096737  -0.007674   0.003796  0.026974
# targeted_productivity  -0.088557   0.032768  -0.056181 -0.053818
# smv                     0.674887   0.032629   0.056863  0.105901
# wip                     0.022302   0.167210  -0.026299 -0.048718
# over_time               1.000000  -0.004793   0.031038 -0.017913
# incentive              -0.004793   1.000000  -0.012024 -0.021140
# idle_time               0.031038  -0.012024   1.000000  0.559146
# idle_men               -0.017913  -0.021140   0.559146  1.000000
# no_of_style_change      0.059790  -0.026607  -0.011598  0.133632
# no_of_workers           0.734164   0.049222   0.058049  0.106946
# actual_productivity    -0.054206   0.076538  -0.080851 -0.181734
#
#                        no_of_style_change  no_of_workers  actual_productivity
# team                            -0.011194      -0.075113            -0.148753
# targeted_productivity           -0.209294      -0.084288             0.421594
# smv                              0.315388       0.912176            -0.122089
# wip                             -0.072357       0.030383             0.131147
# over_time                        0.059790       0.734164            -0.054206
# incentive                       -0.026607       0.049222             0.076538
# idle_time                       -0.011598       0.058049            -0.080851
# idle_men                         0.133632       0.106946            -0.181734
# no_of_style_change               1.000000       0.327787            -0.207366
# no_of_workers                    0.327787       1.000000            -0.057991
# actual_productivity             -0.207366      -0.057991             1.000000
